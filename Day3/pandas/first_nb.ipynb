# %% [markdown]
# https://www.academis.eu/pandas_go_to_space/
#
#
# jupyter notebook
# ** shortcuts**
# - shift + enter - executes a cell
# - Esc + a - creates a new cell above
# - Esc + ba - creates a new cell below
# - Esc + x deletes a cell
# - Esc + y/m converts cell type to Python/Markdown
#
# math formulas use LaTeX notation: $\sum X_i ^ 24

# %%
# execute arbitrary terminal commands
# !python -m pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
print("hello workds")
# Out:
# hello workds

# %%
import pandas as pd
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 import pandas as pd
# ----> 2 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
#create a table with columns/rows
pd.DataFrame({
    "planets":["pandalor", "tatooine", "hoth","naboo"],
    "size":[10, 11, 12, 13]
})
# Out:
#     planets  size
# 0  pandalor    10
# 1  tatooine    11
# 2      hoth    12
# 3     naboo    13

# %%
df = pd.DataFrame({
    "planets":["pandalor", "tatooine", "hoth","naboo"],
    "size":[10, 11, 12, 13]
})
df
# Out:
#     planets  size
# 0  pandalor    10
# 1  tatooine    11
# 2      hoth    12
# 3     naboo    13

# %% [markdown]
# https://www.academis.eu/pandas_go_to_space/read_write_data/README.html

# %%
import pandas as pd

df = pd.read_csv('panda_sector.csv', index_col=0, sep=',', header=0)

# %%
df = pd.read_excel('penguin_sector.xlsx', index_col=0)
df.head(3)
# Out:
#             name          x          y          z class  size
# 300      Tarakis  35.387138  75.818501  45.896348     B    18
# 301  Boradis III  95.862718  74.342379  91.938740     A     6
# 302  Nelvana III  18.437092  61.194051  17.609547     M     3

# %%
df.to_csv('penguin_sector_output.csv')

# %%
# !python -m pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

conn = create_engine('postgres//user:psw@host:port/dbname')
df = pd.read_sql('SELECT * FROM penguins', conn)
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[16], line 3
#       1 from sqlalchemy import create_engine
# ----> 3 conn = create_engine('postgres//user:psw@host:port/dbname')
#       4 df = pd.read_sql('SELECT * FROM penguins', conn)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File c:\Users\bbeuka\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# ...

# %%
pd.read_clipboard()
# Out:
#                                                           from sqlalchemy  \
# conn = create_engine('postgres//user:psw@host:port/dbn...
# df   = pd.read_sql('SELECT                                   *       FROM
#
#                                                                import  \
# conn = create_engine('postgres//user:psw@host:port/dbn...
# df   = pd.read_sql('SELECT                                 penguins',
#
#                                                           create_engine
# conn = create_engine('postgres//user:psw@host:port/dbn...
# df   = pd.read_sql('SELECT                                        conn)
