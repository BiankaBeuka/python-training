# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 import seaborn as sns
#       3 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df = pd.read_csv('panda_sector.csv')
df.head(3)
# Out:
#    Unnamed: 0         name          x          y          z class  size
# 0           0       Dakala  89.964740  17.844597  60.575530     B     4
# 1           1    Aucdet IX  60.755522  31.227179  91.873471     C     8
# 2           2  Miridian VI  24.435316  23.024617  36.226809     B    16

# %%
df = pd.read_csv('panda_sector.csv', index_col=0)
df
# Out:
#                  name          x          y          z class  size
# 0              Dakala  89.964740  17.844597  60.575530     B     4
# 1           Aucdet IX  60.755522  31.227179  91.873471     C     8
# 2         Miridian VI  24.435316  23.024617  36.226809     B    16
# 3    Tarlac homeworld  49.824770  20.618616  72.571646     B    16
# 4        Davlos Prime  33.034848  63.796079  89.445256     M     4
# ..                ...        ...        ...        ...   ...   ...
# 295             Lysia  57.329438  96.512974  49.823600     B    16
# 296          Caleb IV  83.810696  48.839413  40.667407     B     4
# 297           Otar II  40.438150  15.067611  95.302002     B     1
# 298          Balancar  77.091138  34.238364  52.253972     A    13
# 299            Varala  42.203606  41.341645  21.911748     M     4
#
# [300 rows x 6 columns]

# %% [markdown]
# # BAR plot

# %%
from matplotlib import pyplot as plt

# %%
df["x"].head(5).plot.bar()
plt.show()
plt.figure(figsize=(10,6))

# %%
# line plot
df["x"].plot()
plt.figure(figsize=(10,6))

# %%
# line plot
df[["x","y"]].plot()
plt.figure(figsize=(10,6))

# %%
df[["x","y"]].iloc[:50].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Histogram

# %%
import seaborn as sns

# %%
sns.histplot(data=df["size"], bins=30, kde=True)
# Out:
# <Axes: xlabel='size', ylabel='Count'>

# %%
# box plot

sns.boxplot(data=df, y="y", hue="class")
# Out:
# <Axes: ylabel='y'>

# %%
sns.boxplot(data=df, y="y", hue="class", gap=0.2)
# Out:
# <Axes: ylabel='y'>
