# %%
import math
# how does Python find a module?
# 1. builtin standard modules (relative path from the Python interpreter)

math.__file__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       1 import math
#       2 # how does Python find a module?
#       3 # 1. builtin standard modules (relative path from the Python interpreter)
# ----> 5 math.__file__
#
# AttributeError: module 'math' has no attribute '__file__'

# %%
math
# Out:
# <module 'math' (built-in)>

# %%
# there is a math.py or somewhere store in python

# %%
# 2. installable library
import pydantic
pydantic.__file__
# Out:
# 'c:\\Users\\bbeuka\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\pydantic\\__init__.py'

# %%
# instalable libraries are ussualy in site-packages folder of your Python installation
import sys
sys.path
# Out:
# ['c:\\Users\\bbeuka\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip',
#  'c:\\Users\\bbeuka\\AppData\\Local\\Programs\\Python\\Python313\\DLLs',
#  'c:\\Users\\bbeuka\\AppData\\Local\\Programs\\Python\\Python313\\Lib',
#  'c:\\Users\\bbeuka\\AppData\\Local\\Programs\\Python\\Python313',
#  '',
#  'C:\\Users\\bbeuka\\AppData\\Roaming\\Python\\Python313\\site-packages',
#  'c:\\Users\\bbeuka\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages']

# %%
# when you import something, Python loops through the folder in sys.path and searches in each of them

# use the PYTHONPATH environment variable to add additional folders to sys.path

# '' - empty string - current working directory, and I can import from there
