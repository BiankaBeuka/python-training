# %%
dest=["orion arm","alpha centauri","sirius","vega","polaris"]
dest.sort()
print(dest)
# Out:
# ['alpha centauri', 'orion arm', 'polaris', 'sirius', 'vega']

# %%
for d in dest:
    print("You can travel to: "+d)
# Out:
# You can travel to: alpha centauri
# You can travel to: orion arm
# You can travel to: polaris
# You can travel to: sirius
# You can travel to: vega

# %%
dest[1]="andromeda"
print(dest)
# Out:
# ['alpha centauri', 'andromeda', 'polaris', 'sirius', 'vega']

# %%
dest.append("milky way")
print(dest)
# Out:
# ['alpha centauri', 'andromeda', 'polaris', 'sirius', 'vega', 'milky way']

# %%
dest.insert(2,"whirlpool galaxy")
print(dest)
# Out:
# ['alpha centauri', 'andromeda', 'whirlpool galaxy', 'polaris', 'sirius', 'vega', 'milky way']

# %%
dest + ["sombrero galaxy","pinwheel galaxy"]
# Out:
# ['alpha centauri',
#  'andromeda',
#  'whirlpool galaxy',
#  'polaris',
#  'sirius',
#  'vega',
#  'milky way',
#  'sombrero galaxy',
#  'pinwheel galaxy']

# %%
dest += ['black holww']

# %%
dest.pop() # from the end, or pop(0) but it is inefficient
# Out:
# 'milky way'

# %%
#copying a list
new = dest
dest.append("new place")
print("dest:",dest)
print("new:",new)
# Out:
# dest: ['alpha centauri', 'andromeda', 'whirlpool galaxy', 'polaris', 'sirius', 'vega', 'new place', 'new place']
# new: ['alpha centauri', 'andromeda', 'whirlpool galaxy', 'polaris', 'sirius', 'vega', 'new place', 'new place']

# %%
new = dest.copy()
dest.append("another place")
print(new)
# Out:
# ['alpha centauri', 'andromeda', 'whirlpool galaxy', 'polaris', 'sirius', 'vega', 'new place', 'new place', 'another place', 'another place']

# %%
# if you list contains other data tructures
from copy import deepcopy
dest.append([1,2,3])
print(dest)
# Out:
# ['alpha centauri', 'andromeda', 'whirlpool galaxy', 'polaris', 'sirius', 'vega', 'new place', 'new place', 'another place', 'another place', 'another place', [1, 2, 3]]

# %%
new = dest.copy()
dest[-1][0]=999
dest[-1].append(4)
print("dest:",dest)
print("new:",new)
# Out:
# dest: ['alpha centauri', 'andromeda', 'whirlpool galaxy', 'polaris', 'sirius', 'vega', 'new place', 'new place', 'another place', 'another place', 'another place', [999, 2, 3, 4, 4, 4]]
# new: ['alpha centauri', 'andromeda', 'whirlpool galaxy', 'polaris', 'sirius', 'vega', 'new place', 'new place', 'another place', 'another place', 'another place', [999, 2, 3, 4, 4, 4]]

# %%
#use deepdcopy
new2= deepcopy(dest)
dest[-1][0]=111
print("dest:",dest)
print("new2:",new2)
# Out:
# dest: ['alpha centauri', 'andromeda', 'whirlpool galaxy', 'polaris', 'sirius', 'vega', 'new place', 'new place', 'another place', 'another place', 'another place', [111, 2, 3, 4, 4, 4]]
# new2: ['alpha centauri', 'andromeda', 'whirlpool galaxy', 'polaris', 'sirius', 'vega', 'new place', 'new place', 'another place', 'another place', 'another place', [111, 2, 3, 4, 4, 4]]
