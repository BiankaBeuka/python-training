# %%
#strings
s="fory two"

# %%
print(s)
# Out:
# fory two

# %%
list(s)
# Out:
# ['f', 'o', 'r', 'y', ' ', 't', 'w', 'o']

# %%
s[1:4]
print(s[1:4])
# Out:
# ory

# %%
s[3:13:2]
# Out:
# 'yto'

# %%
s[20:3:-1]
# Out:
# 'owt '
